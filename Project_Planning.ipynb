# %% [markdown]
# 1) Data Description
# Observations and variables:
# There are 1535 observations and 5 variables in the sessions dataset. There are 196 observations and 7 variables in the players dataset.
#
# Summary Statistics for sessions:
# original_start_time: Median: 1.72e+12, Mean: 1.72e+12
#
# original_end_time: Median: 1.72e+12, Mean 1.72e+12
#
# Summary Statistics for players:
# played_hours: Median: 0.10, Mean: 5.85
#
# Age: Median 19.00, Mean 21.14
#
# Name and Type of variables of sessions:
# | Variable             | Type      | Meaning                                   |
# |----------------------|-----------|-------------------------------------------|
# | hashedEmail          | character | A series of characters used to identify players           |
# | start_time           | character | Time that player logs on        |
# | end_time             | character | Time that player logs off          |
# | original_start_time  | numeric   | timestamp for start time        |
# | original_end_time    | numeric   | timestamp for end time          |
#
# Name and Type of variables of players:
# | Variable    | Type      | Meaning                                        |
# |-------------|-----------|------------------------------------------------|
# | experience  | character | Experience level of player |
# | subscribe   | logical   | Whether the player is subscribed  |
# | hashedEmail | character | A series of characters used to identify players                |
# | played_hours| numeric   | Total hours the player has played              |
# | name        | character | Player's name                                  |
# | gender      | character | Player's gender                                |
# | Age         | numeric   | Age of the player                              |
#
# issues with sessions:
# The Start_time and End_time variables are stored as strings with both the date and the time included. Hashed email has repeated values, meaning a player may have multiple sessions. Original
#
# Issues with players:
# The age variable has 2 NAs. Played_hours has many 0s likely because their playtime did not reach 10 minutes. Gender has multiple has 7 different values.
#
# Issues that may not be seen:
#
# - Sessions dataset was probably collected by an automatic platform
# - Players dataset was probably collected through surveys that were not filtered.
# - Session durations are hard to determine

# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(dplyr)
library(tidyr)
library(ggplot2)

# %%
# Out:
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “There were 2 warnings in `mutate()`.
# The first warning was:
# ℹ In argument: `start_time = round(...)`.
# Caused by warning:
# ! NAs introduced by coercion
# ...

# %% [markdown]
# 5) https://github.com/daniel30c/ProjectPlanning.git
